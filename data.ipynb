# %%
from roboflow import Roboflow

rf = Roboflow(api_key="v3w5oSKOlabkvi3ugvih")

project = rf.workspace("sportsanalysis-3mrde").project("tennis-ball-and-court-detection-4qpqa")
version = project.version(1)
dataset = version.download("yolov11", location="/home/rwang2000/datasets/tennis-ball-and-court-detection-4qpqa")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       5 project = rf.workspace("sportsanalysis-3mrde").project("tennis-ball-and-court-detection-4qpqa")
#       6 version = project.version(1)
# ----> 7 dataset = version.download("yolov11", location="/home/rwang2000/datasets/tennis-ball-and-court-detection-4qpqa")
#
# File ~/miniforge3/envs/py312/lib/python3.12/site-packages/roboflow/core/version.py:232, in Version.download(self, model_format, location, overwrite)
#     229         except json.JSONDecodeError:
#     230             response.raise_for_status()
# --> 232 self.__download_zip(link, location, model_format)
#     233 self.__extract_zip(location, model_format)
#     234 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
#
# ...
